# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/MyDrive
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive
# 'Old Stuff'   WaveSpectra

# %%
# !git clone https://github.com/Dedini91/WaveSpectra_CAE.git
# Out:
# Cloning into 'WaveSpectra_CAE'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 71 (delta 21), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (71/71), 129.69 KiB | 170.00 KiB/s, done.

# %%
# %cd WaveSpectra_CAE/
# Out:
# /content/gdrive/MyDrive/WaveSpectra_CAE

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 1)) (3.7.1)
# Collecting numpy==1.24.2
#   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 74.7 MB/s eta 0:00:00
# Collecting pandas==2.0.0
#   Downloading pandas-2.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 85.3 MB/s eta 0:00:00
# Collecting Pillow==9.5.0
#   Downloading Pillow-9.5.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 93.7 MB/s eta 0:00:00
# Collecting prettytable==3.7.0
#   Downloading prettytable-3.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: torch==2.0.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 6)) (2.0.0+cu118)
# Collecting torchinfo==1.7.2
#   Downloading torchinfo-1.7.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: torchvision==0.15.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 8)) (0.15.1+cu118)
# Requirement already satisfied: tqdm==4.65.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 9)) (4.65.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 10)) (4.7.0.72)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 11)) (2.12.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 1)) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 1)) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 1)) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.9/dist-packages (from pandas==2.0.0->-r requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas==2.0.0->-r requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prettytable==3.7.0->-r requirements.txt (line 5)) (0.2.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->-r requirements.txt (line 6)) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->-r requirements.txt (line 6)) (3.11.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->-r requirements.txt (line 6)) (3.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==2.0.0->-r requirements.txt (line 6)) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision==0.15.1->-r requirements.txt (line 8)) (2.27.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch==2.0.0->-r requirements.txt (line 6)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch==2.0.0->-r requirements.txt (line 6)) (16.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 11)) (2.17.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 11)) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 11)) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 11)) (2.2.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 11)) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 11)) (67.6.1)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 11)) (1.53.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 11)) (0.40.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 11)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 11)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 11)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 11)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib==3.7.1->-r requirements.txt (line 1)) (3.15.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard->-r requirements.txt (line 11)) (6.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision==0.15.1->-r requirements.txt (line 8)) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision==0.15.1->-r requirements.txt (line 8)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision==0.15.1->-r requirements.txt (line 8)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision==0.15.1->-r requirements.txt (line 8)) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 11)) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch==2.0.0->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 11)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 11)) (3.2.2)
# Installing collected packages: torchinfo, prettytable, Pillow, numpy, pandas
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 0.7.2
#     Uninstalling prettytable-0.7.2:
#       Successfully uninstalled prettytable-0.7.2
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.2 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.
# ipython-sql 0.4.1 requires prettytable<1, but you have prettytable 3.7.0 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.5.3, but you have pandas 2.0.0 which is incompatible.
# Successfully installed Pillow-9.5.0 numpy-1.24.2 pandas-2.0.0 prettytable-3.7.0 torchinfo-1.7.2

# %% [markdown]
# # Preprocess & create dataset

# %%
# !python path/to/make_dataset.py --data path/to/data/folder

# %% [markdown]
# # Training

# %%
# !python /content/gdrive/MyDrive/WaveSpectra_CAE/train.py -n exp_name -d "/content/gdrive/MyDrive/WaveSpectra_CAE/data/processed" -b 1 -e 10 -o adamw -l l1 --reduction sum --lr 0.00003 --prototyping --verbose
# Out:
# 2023-04-17 19:03:34.186862: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-17 19:03:35.578491: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Arguments parsed - Current configuration:
# verbose         True
# name            exp_name
# data            /content/gdrive/MyDrive/WaveSpectra_CAE/data/processed
# prototyping     True
# model_path      None
# device          cuda
# num_epochs      10
# batch_size      1
# lr              3e-05
# optimizer       adamw
# loss            l1
# reduction       sum
# momentum        0.9
# scheduler       True
# lr_min          1e-05
# decay           0.0
# interval        5
#
# Created folder structure for experiment:
# results/exp_name/04-17_1903
# results/exp_name/04-17_1903/logs
# results/exp_name/04-17_1903/model
# results/exp_name/04-17_1903/metrics
# results/exp_name/04-17_1903/predictions/training
# results/exp_name/04-17_1903/predictions/validation
# results/exp_name/04-17_1903/predictions/evaluation
# ==========================================================================================
#
# Device:	cuda
# ==========================================================================================
# Basic dataset information:
# Train set mean/std:	0.1176469/0.00040002
# +------------+---------+------------+----------+---------------+
# |            | # pairs | Dimensions | # pixels |    Datatype   |
# +------------+---------+------------+----------+---------------+
# |   Train    |   200   |  [64, 64]  |   4096   | torch.float32 |
# | Validation |   200   |  [64, 64]  |   4096   | torch.float32 |
# |    Test    |   300   |  [64, 64]  |   4096   | torch.float32 |
# +------------+---------+------------+----------+---------------+
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CAE                                      [1, 1, 64, 64]            --
# ├─Conv2d: 1-1                            [1, 64, 32, 32]           1,664
# │    └─weight                                                      ├─1,600
# │    └─bias                                                        └─64
# ├─LeakyReLU: 1-2                         [1, 64, 32, 32]           --
# ├─Conv2d: 1-3                            [1, 128, 16, 16]          73,856
# │    └─weight                                                      ├─73,728
# │    └─bias                                                        └─128
# ├─LeakyReLU: 1-4                         [1, 128, 16, 16]          --
# ├─Conv2d: 1-5                            [1, 192, 16, 16]          221,376
# │    └─weight                                                      ├─221,184
# │    └─bias                                                        └─192
# ├─LeakyReLU: 1-6                         [1, 192, 16, 16]          --
# ├─Conv2d: 1-7                            [1, 256, 16, 16]          442,624
# │    └─weight                                                      ├─442,368
# │    └─bias                                                        └─256
# ├─LeakyReLU: 1-8                         [1, 256, 16, 16]          --
# ├─Conv2d: 1-9                            [1, 512, 64, 64]          1,180,160
# │    └─weight                                                      ├─1,179,648
# │    └─bias                                                        └─512
# ├─LeakyReLU: 1-10                        [1, 512, 64, 64]          --
# ├─Conv2d: 1-11                           [1, 256, 64, 64]          1,179,904
# │    └─weight                                                      ├─1,179,648
# │    └─bias                                                        └─256
# ├─LeakyReLU: 1-12                        [1, 256, 64, 64]          --
# ├─Conv2d: 1-13                           [1, 128, 64, 64]          295,040
# │    └─weight                                                      ├─294,912
# │    └─bias                                                        └─128
# ├─LeakyReLU: 1-14                        [1, 128, 64, 64]          --
# ├─Conv2d: 1-15                           [1, 64, 64, 64]           73,792
# │    └─weight                                                      ├─73,728
# │    └─bias                                                        └─64
# ├─LeakyReLU: 1-16                        [1, 64, 64, 64]           --
# ├─Conv2d: 1-17                           [1, 1, 64, 64]            577
# │    └─weight                                                      ├─576
# │    └─bias                                                        └─1
# ==========================================================================================
# Total params: 3,468,993
# Trainable params: 3,468,993
# Non-trainable params: 0
# Total mult-adds (G): 11.37
# ==========================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 33.19
# Params size (MB): 13.88
# Estimated Total Size (MB): 47.09
# ==========================================================================================
# Number of epochs: 10
# Total samples: 200
# Batch size: 1
# # iterations: 200
# ==========================================================================================
# Using cosine learning rate annealing:
# Max lr: 3e-05 - Min lr: 1e-05
# Setup complete!
# ==========================================================================================
# ==========================================================================================
# Training Model...
# Epoch 1/10: 100% 200/200 [00:03<00:00, 61.15batch/s, loss=37.3]
#           : 100% 200/200 [02:57<00:00,  1.13batch/s, loss=37.5]
# New best model and optimizer saved!
# Train loss: 71.584855	Validation loss: 65.350640	Learning rate: 3.0000e-05
# Epoch 2/10: 100% 200/200 [00:03<00:00, 60.33batch/s, loss=72.5]
#           : 100% 200/200 [00:01<00:00, 134.06batch/s, loss=60.7]
# Train loss: 58.637802	Validation loss: 58.178573	Learning rate: 2.9511e-05
# Epoch 3/10: 100% 200/200 [00:03<00:00, 63.17batch/s, loss=52.2]
#           : 100% 200/200 [00:01<00:00, 135.33batch/s, loss=33.5]
# New best model and optimizer saved!
# Train loss: 53.371403	Validation loss: 52.239369	Learning rate: 2.8090e-05
# Epoch 4/10: 100% 200/200 [00:03<00:00, 62.61batch/s, loss=40.8]
#           : 100% 200/200 [00:01<00:00, 141.35batch/s, loss=60.3]
# Train loss: 51.356294	Validation loss: 54.020522	Learning rate: 2.5878e-05
# Epoch 5/10: 100% 200/200 [00:03<00:00, 59.27batch/s, loss=89.1]
#           : 100% 200/200 [00:01<00:00, 135.27batch/s, loss=48]
# Saved model checkpoint
# Train loss: 50.668549	Validation loss: 53.635760	Learning rate: 2.3090e-05
# Epoch 6/10: 100% 200/200 [00:03<00:00, 62.01batch/s, loss=21.6]
#           : 100% 200/200 [00:01<00:00, 145.84batch/s, loss=68.5]
# Train loss: 48.003915	Validation loss: 50.663847	Learning rate: 2.0000e-05
# Epoch 7/10: 100% 200/200 [00:03<00:00, 61.03batch/s, loss=58.1]
#           : 100% 200/200 [00:01<00:00, 136.33batch/s, loss=25.2]
# New best model and optimizer saved!
# Train loss: 46.822974	Validation loss: 51.464274	Learning rate: 1.6910e-05
# Epoch 8/10: 100% 200/200 [00:03<00:00, 59.04batch/s, loss=63.6]
#           : 100% 200/200 [00:01<00:00, 129.95batch/s, loss=43.2]
# Train loss: 45.850029	Validation loss: 52.289186	Learning rate: 1.4122e-05
# Epoch 9/10: 100% 200/200 [00:03<00:00, 60.59batch/s, loss=74.2]
#           : 100% 200/200 [00:01<00:00, 142.32batch/s, loss=76.2]
# Train loss: 45.115487	Validation loss: 50.000127	Learning rate: 1.1910e-05
# Epoch 10/10: 100% 200/200 [00:03<00:00, 60.83batch/s, loss=27.4]
#            : 100% 200/200 [00:01<00:00, 130.01batch/s, loss=28.3]
# Saved model checkpoint
# Train loss: 44.054523	Validation loss: 50.590307	Learning rate: 1.0489e-05
#    Epoch  ...  Huber (mean)
# 0     10  ...      0.000876
#
# [1 rows x 7 columns]
#
# Training complete!
# Best training loss:	44.054523
# Best validation loss:	50.000127
# ==========================================================================================
#
# results_validation:
#       Image ID  ...  Huber (mean)
# 52   17612.jpg  ...      0.000318
# 175  14721.jpg  ...      0.000300
# 33   14801.jpg  ...      0.000271
# 197  18701.jpg  ...      0.000539
# 137  14063.jpg  ...      0.000391
# ..         ...  ...           ...
# 17   13003.jpg  ...      0.002046
# 4    14814.jpg  ...      0.003520
# 133  16365.jpg  ...      0.002059
# 193  18769.jpg  ...      0.004985
# 87   12579.jpg  ...      0.006367
#
# [200 rows x 7 columns]
# Evaluating model...
# model_path not supplied - loading : results/exp_name/04-17_1903/model/best_model.pth
# Evaluating:  66% 197/300 [03:41<01:55,  1.12s/batch]
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/WaveSpectra_CAE/train.py", line 494, in <module>
#     evaluate()
#   File "/content/gdrive/MyDrive/WaveSpectra_CAE/train.py", line 431, in evaluate
#     for data, target, data_index, target_index in tepoch:
#   File "/usr/local/lib/python3.9/dist-packages/tqdm/std.py", line 1178, in __iter__
#     for obj in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py", line 634, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py", line 678, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/content/gdrive/MyDrive/WaveSpectra_CAE/utils/dataset.py", line 23, in __getitem__
#     x = Image.open(self.data_paths[index])
#   File "/usr/local/lib/python3.9/dist-packages/PIL/Image.py", line 3245, in open
#     prefix = fp.read(16)
# KeyboardInterrupt
# ^C

# %%
# !python evaluate.py --model_path "/content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name/04-17_1903/model/best_model.pth" --img_path "/content/gdrive/MyDrive/WaveSpectra_CAE/data/processed/red_x_test" --target_path "/content/gdrive/MyDrive/WaveSpectra_CAE/data/processed/red_y_train" --verbose
# Out:
# 2023-04-17 19:20:11.547150: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-17 19:20:12.460879: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Arguments parsed
# verbose         True
# model_path      /content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name/04-17_1903/model/best_model.pth
# img_path        /content/gdrive/MyDrive/WaveSpectra_CAE/data/processed/red_x_test
# target_path     /content/gdrive/MyDrive/WaveSpectra_CAE/data/processed/red_y_train
# device          cuda
# errmaps         True
# loss            l1
# reduction       sum
#
# Created folders within referenced experiment:
# /content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name
# /content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name/04-17_1903/evaluation/04-17_1920/logs
# /content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name/04-17_1903/model/best_model.pth
# /content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name/04-17_1903/evaluation/04-17_1920/metrics
# ==========================================================================================
#
# Device:	cuda
# /content/gdrive/MyDrive/WaveSpectra_CAE/data/processed/red_x_test
# /content/gdrive/MyDrive/WaveSpectra_CAE/data/processed/red_y_train
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CAE                                      [1, 1, 64, 64]            --
# ├─Conv2d: 1-1                            [1, 64, 32, 32]           1,664
# │    └─weight                                                      ├─1,600
# │    └─bias                                                        └─64
# ├─LeakyReLU: 1-2                         [1, 64, 32, 32]           --
# ├─Conv2d: 1-3                            [1, 128, 16, 16]          73,856
# │    └─weight                                                      ├─73,728
# │    └─bias                                                        └─128
# ├─LeakyReLU: 1-4                         [1, 128, 16, 16]          --
# ├─Conv2d: 1-5                            [1, 192, 16, 16]          221,376
# │    └─weight                                                      ├─221,184
# │    └─bias                                                        └─192
# ├─LeakyReLU: 1-6                         [1, 192, 16, 16]          --
# ├─Conv2d: 1-7                            [1, 256, 16, 16]          442,624
# │    └─weight                                                      ├─442,368
# │    └─bias                                                        └─256
# ├─LeakyReLU: 1-8                         [1, 256, 16, 16]          --
# ├─Conv2d: 1-9                            [1, 512, 64, 64]          1,180,160
# │    └─weight                                                      ├─1,179,648
# │    └─bias                                                        └─512
# ├─LeakyReLU: 1-10                        [1, 512, 64, 64]          --
# ├─Conv2d: 1-11                           [1, 256, 64, 64]          1,179,904
# │    └─weight                                                      ├─1,179,648
# │    └─bias                                                        └─256
# ├─LeakyReLU: 1-12                        [1, 256, 64, 64]          --
# ├─Conv2d: 1-13                           [1, 128, 64, 64]          295,040
# │    └─weight                                                      ├─294,912
# │    └─bias                                                        └─128
# ├─LeakyReLU: 1-14                        [1, 128, 64, 64]          --
# ├─Conv2d: 1-15                           [1, 64, 64, 64]           73,792
# │    └─weight                                                      ├─73,728
# │    └─bias                                                        └─64
# ├─LeakyReLU: 1-16                        [1, 64, 64, 64]           --
# ├─Conv2d: 1-17                           [1, 1, 64, 64]            577
# │    └─weight                                                      ├─576
# │    └─bias                                                        └─1
# ==========================================================================================
# Total params: 3,468,993
# Trainable params: 3,468,993
# Non-trainable params: 0
# Total mult-adds (G): 11.37
# ==========================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 33.19
# Params size (MB): 13.88
# Estimated Total Size (MB): 47.09
# ==========================================================================================
# Total samples: 300
# Batch size: 1
# # iterations: 300
# ==========================================================================================
# Setup complete!
# ==========================================================================================
# ==========================================================================================
# Evaluating model...
# Loading model from supplied model_path: /content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name/04-17_1903/model/best_model.pth
# Evaluating:  67% 200/300 [02:23<01:11,  1.39batch/s]
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/WaveSpectra_CAE/evaluate.py", line 248, in <module>
#     evaluate()
#   File "/content/gdrive/MyDrive/WaveSpectra_CAE/evaluate.py", line 172, in evaluate
#     for data, target, data_index, target_index in tepoch:
#   File "/usr/local/lib/python3.9/dist-packages/tqdm/std.py", line 1178, in __iter__
#     for obj in iterable:
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py", line 634, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py", line 678, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/content/gdrive/MyDrive/WaveSpectra_CAE/utils/dataset.py", line 21, in __getitem__
#     y_idx = self.target_paths[index].replace('\\', '/').split('/')[-1]
# IndexError: list index out of range

# %% [markdown]
# # Inference: Prediction/Generation

# %%
# !python predict.py --model_path "/content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name/04-17_1903/model/best_model.pth" --img_path "/content/gdrive/MyDrive/WaveSpectra_CAE/data/processed/red_x_test"
# Out:
# 2023-04-17 19:25:34.458093: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-17 19:25:35.369486: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Arguments parsed
# model_path      /content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name/04-17_1903/model/best_model.pth
# img_path        /content/gdrive/MyDrive/WaveSpectra_CAE/data/processed/red_x_test
# device          cuda
#
# Created folders within referenced experiment:
# /content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name
# /content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name/04-17_1903/model/best_model.pth
#
# Device:	cuda
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CAE                                      [1, 1, 64, 64]            --
# ├─Conv2d: 1-1                            [1, 64, 32, 32]           1,664
# │    └─weight                                                      ├─1,600
# │    └─bias                                                        └─64
# ├─LeakyReLU: 1-2                         [1, 64, 32, 32]           --
# ├─Conv2d: 1-3                            [1, 128, 16, 16]          73,856
# │    └─weight                                                      ├─73,728
# │    └─bias                                                        └─128
# ├─LeakyReLU: 1-4                         [1, 128, 16, 16]          --
# ├─Conv2d: 1-5                            [1, 192, 16, 16]          221,376
# │    └─weight                                                      ├─221,184
# │    └─bias                                                        └─192
# ├─LeakyReLU: 1-6                         [1, 192, 16, 16]          --
# ├─Conv2d: 1-7                            [1, 256, 16, 16]          442,624
# │    └─weight                                                      ├─442,368
# │    └─bias                                                        └─256
# ├─LeakyReLU: 1-8                         [1, 256, 16, 16]          --
# ├─Conv2d: 1-9                            [1, 512, 64, 64]          1,180,160
# │    └─weight                                                      ├─1,179,648
# │    └─bias                                                        └─512
# ├─LeakyReLU: 1-10                        [1, 512, 64, 64]          --
# ├─Conv2d: 1-11                           [1, 256, 64, 64]          1,179,904
# │    └─weight                                                      ├─1,179,648
# │    └─bias                                                        └─256
# ├─LeakyReLU: 1-12                        [1, 256, 64, 64]          --
# ├─Conv2d: 1-13                           [1, 128, 64, 64]          295,040
# │    └─weight                                                      ├─294,912
# │    └─bias                                                        └─128
# ├─LeakyReLU: 1-14                        [1, 128, 64, 64]          --
# ├─Conv2d: 1-15                           [1, 64, 64, 64]           73,792
# │    └─weight                                                      ├─73,728
# │    └─bias                                                        └─64
# ├─LeakyReLU: 1-16                        [1, 64, 64, 64]           --
# ├─Conv2d: 1-17                           [1, 1, 64, 64]            577
# │    └─weight                                                      ├─576
# │    └─bias                                                        └─1
# ==========================================================================================
# Total params: 3,468,993
# Trainable params: 3,468,993
# Non-trainable params: 0
# Total mult-adds (G): 11.37
# ==========================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 33.19
# Params size (MB): 13.88
# Estimated Total Size (MB): 47.09
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CAE                                      [1, 1, 64, 64]            --
# ├─Conv2d: 1-1                            [1, 64, 32, 32]           1,664
# │    └─weight                                                      ├─1,600
# │    └─bias                                                        └─64
# ├─LeakyReLU: 1-2                         [1, 64, 32, 32]           --
# ├─Conv2d: 1-3                            [1, 128, 16, 16]          73,856
# │    └─weight                                                      ├─73,728
# │    └─bias                                                        └─128
# ├─LeakyReLU: 1-4                         [1, 128, 16, 16]          --
# ├─Conv2d: 1-5                            [1, 192, 16, 16]          221,376
# │    └─weight                                                      ├─221,184
# │    └─bias                                                        └─192
# ├─LeakyReLU: 1-6                         [1, 192, 16, 16]          --
# ├─Conv2d: 1-7                            [1, 256, 16, 16]          442,624
# │    └─weight                                                      ├─442,368
# │    └─bias                                                        └─256
# ├─LeakyReLU: 1-8                         [1, 256, 16, 16]          --
# ├─Conv2d: 1-9                            [1, 512, 64, 64]          1,180,160
# │    └─weight                                                      ├─1,179,648
# │    └─bias                                                        └─512
# ├─LeakyReLU: 1-10                        [1, 512, 64, 64]          --
# ├─Conv2d: 1-11                           [1, 256, 64, 64]          1,179,904
# │    └─weight                                                      ├─1,179,648
# │    └─bias                                                        └─256
# ├─LeakyReLU: 1-12                        [1, 256, 64, 64]          --
# ├─Conv2d: 1-13                           [1, 128, 64, 64]          295,040
# │    └─weight                                                      ├─294,912
# │    └─bias                                                        └─128
# ├─LeakyReLU: 1-14                        [1, 128, 64, 64]          --
# ├─Conv2d: 1-15                           [1, 64, 64, 64]           73,792
# │    └─weight                                                      ├─73,728
# │    └─bias                                                        └─64
# ├─LeakyReLU: 1-16                        [1, 64, 64, 64]           --
# ├─Conv2d: 1-17                           [1, 1, 64, 64]            577
# │    └─weight                                                      ├─576
# │    └─bias                                                        └─1
# ==========================================================================================
# Total params: 3,468,993
# Trainable params: 3,468,993
# Non-trainable params: 0
# Total mult-adds (G): 11.37
# ==========================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 33.19
# Params size (MB): 13.88
# Estimated Total Size (MB): 47.09
# ==========================================================================================
# Total samples: 300
# Batch size: 1
# # iterations: 300
# Setup complete!
# ==========================================================================================
# ==========================================================================================
# Evaluating model...
# Loading model from supplied model_path: /content/gdrive/MyDrive/WaveSpectra_CAE/results/exp_name/04-17_1903/model/best_model.pth
# Inference: 100% 300/300 [00:18<00:00, 15.81batch/s]
